# %%
import networkx as nx 
g=nx.barbell_graph(4,3)
# g=nx.cycle_graph(5)
# g=nx.ladder_graph(5)
# g=nx.path_graph(5)
# g=nx.star_graph(4)
g=nx.wheel_graph(5)
# g=nx.gnp_random_graph(5,0.5)
nx.draw(g)

# %%
import networkx as nx
import random
import matplotlib.pyplot as plt 
import operator 
g=nx.gnp_random_graph(10,0.5,directed=True)
nx.draw(g,with_labels=True)
plt.show()
#X is the random source node
x=random.choice([i for i in range(g.number_of_nodes())])
dict_counter={}
for i in range(g.number_of_nodes()):
    dict_counter[i]=0
dict_counter[x]=dict_counter[x]+1
for i in range(100):
    list_n=list(g.neighbors(x))
    if(len(list_n)==0):
        print("If",list_n)
        x=random.choice([i for i in range(G.number_of_nodes())])
    else:
         x=random.choice(list_n)
         dict_counter[x]=dict_counter[x]+1
p=nx.pagerank(g)
sorted_p=sorted(p.items(),key=operator.itemgetter(1))
sorted_rw=sorted(dict_counter.items(),key=operator.itemgetter(1))
print(sorted_p)
print(sorted_rw)
# Out:
# [(0, 0.05388852258967094), (3, 0.057276164139742985), (7, 0.05896005021861077), (5, 0.08674937379385848), (6, 0.08700363777667995), (8, 0.10283758965335171), (1, 0.12275330535983292), (2, 0.12720249681016907), (9, 0.13583367943111854), (4, 0.1674951802269647)]
# [(0, 2), (7, 5), (3, 6), (6, 7), (5, 10), (2, 12), (8, 12), (1, 13), (4, 17), (9, 17)]

# %%
import networkx as nx
import matplotlib.pyplot as plt 
import random
g=nx.DiGraph()
g.add_nodes_from([i for i in range(10)])
node=list(g.nodes())
for s in node:
    for t in node:
        if s!=t:
            r=random.random()
            if r<=0.5:
                g.add_edge(s,t)
nx.draw(g,with_labels=True)
plt.show()

# %% [markdown]
# ## Collatz Conjuction

# %%
n=int(input())
c=1
while(n!=1):
    if n%2==0:
        n=n//2
        c+=1
    else:
        n=3*n+1
        c+=1
print(c)
# Out:
# 8

# %%
import random
print(random.random())
# Out:
# 0.3765686227498458

# %%
import math
p1=[-1,1,4]
p2=[1,3,0]
p3=[-1,1,4]
p4=[0,0,0]
line=math.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2 + (p1[2]-p2[2])**2)
print(line**3)
# Out:
# 117.57550765359252

# %%
import numpy as np
# p1=list(map(float,input().split()))
# p2=list(map(float,input().split()))
# p3=list(map(float,input().split()))
p1=[-1,1,4]
p2=[1,3,0]
p3=[-1,1,4]
n_array = np.array([p1,p2,p3]) 
ans=abs(np.linalg.det(n_array))
g = float("{0:.1f}". format(ans))
print(g,end="")
# Out:
# 0.0

# %%
num=int(input())
ramesh=list(input().split())
suresh=list(input().split())
ans="12345"
marks=0
for i in range(num):
    if ramesh[i]!=suresh[i]: 
        if ramesh[i] in ans and suresh[i] in ans  :
            marks+=1
print(marks,end='')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-0a6f378eec17> in <module>
#       5 marks=0
#       6 for i in range(num):
# ----> 7     if ramesh[i]!=suresh[i]:
#       8         if ramesh[i] in ans and suresh[i] in ans  :
#       9             marks+=1
#
# IndexError: list index out of range

# %%
import math
pq=int(input())
pr=int(input())
qr=(pq*pq+pr*pr)**(0.5)
ans=math.asin(pq/qr)
print (round(math.degrees(ans)),end="")
